# %% [markdown]
# <a href="https://colab.research.google.com/github/tejaswininachan/python-assignment/blob/main/convert_2_list_into_dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
keys = ["name", "age", "city"]
values = ["Tejaswini", 20, "Pune"]

data = dict(zip(keys, values))

print(data)
# Out:
# {'name': 'Tejaswini', 'age': 20, 'city': 'Pune'}
