# %% [markdown]
# <a href="https://colab.research.google.com/github/tejaswininachan/python-assignment/blob/main/check_string_is_palindrome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text = input("Enter a string: ")

reverse = text[::-1]

if text == reverse:
    print("Palindrome")
else:
    print("Not Palindrome")
