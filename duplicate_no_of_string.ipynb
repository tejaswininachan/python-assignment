# %% [markdown]
# <a href="https://colab.research.google.com/github/tejaswininachan/python-assignment/blob/main/duplicate_no_of_string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text = input("Enter a string: ")

result = ""

for char in text:
    if char not in result:
        result += char

print("After removing duplicates:", result)
