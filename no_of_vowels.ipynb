# %% [markdown]
# <a href="https://colab.research.google.com/github/tejaswininachan/python-assignment/blob/main/no_of_vowels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text = input("Enter a string: ")

count = 0

for char in text:
    if char.lower() in "aeiou":
        count += 1

print("Number of vowels:", count)
