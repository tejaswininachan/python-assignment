# %% [markdown]
# <a href="https://colab.research.google.com/github/tejaswininachan/python-assignment/blob/main/second_largest_no_in_list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers = [10, 20, 40, 50, 30]

numbers.sort()

print("Second largest number is:", numbers[-2])
# Out:
# Second largest number is: 40
