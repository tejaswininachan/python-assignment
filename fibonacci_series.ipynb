# %% [markdown]
# <a href="https://colab.research.google.com/github/tejaswininachan/python-assignment/blob/main/fibonacci_series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Enter number of terms: "))

a = 0
b = 1

print("Fibonacci Series:")

for i in range(n):
    print(a)

    c = a + b
    a = b
    b = c
